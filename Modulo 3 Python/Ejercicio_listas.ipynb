# %%
mi_lista = [1 ,2 ,3, 4, 5]
print(mi_lista[4])# Imprime el elemento en la posición 4 de la lista, que es el número 5.
print(mi_lista[-1])# Imprime el último elemento de la lista, que también es el número 5.
mi_lista.append(6)
print(mi_lista)
# Out:
# 5
# 5
# [1, 2, 3, 4, 5, 6]
